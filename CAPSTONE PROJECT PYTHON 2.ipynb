# %%
# signin-> username:== 115050   password:== lpu@123 for admin
from tkinter import *                                   #Importing module
from tkinter.messagebox import*                         #Importing module
from tkinter.simpledialog import*                       #Importing module
window=Tk()#Tk() interface for python gui toolkit
window.title("capstone supervisior portal")#adding the title to window
f=Frame(window,height=1000,width=2000) # frame is used to contain other widgets and frame is placed on the window
f.propagate(0)#it prevent the frame from shrinkage
f.pack()
def l():
    l1.destroy()#destroy the buttons
    l2.destroy() #destroy the buttons
    label55=Label(text="ENTER YOUR CREDENTIALS CAREFULLY ")
    label3=Label(text="NAME :")                               #Adding lables
    label4=Label(text="SURNAME :")
    label5=Label(text="ID  :")
    label6=Label(text="GENDER :")
    label7=Label(text="SECTION :")
    label8=Label(text="SESSION :")
    label9=Label(text="TERM :")
    label10=Label(text="CELL NO. :")
    label11=Label(text="EMAIL ID :")
    label12=Label(text="FIELD :")
    label13=Label(text="TOPIC :")
    e3=Entry(f,width=25)                                     #adding entry
    e4=Entry(f,width=25)
    e5=Entry(f,width=25)
    v1=IntVar()
    v2=IntVar()
    v3=IntVar()
    c1=Checkbutton(f,text="MALE",variable=v1)
    c2=Checkbutton(f,text="FEMALE",variable=v2)          #Adding  Checkbuttons
    c3=Checkbutton(f,text="OTHER",variable=v3)
    e6=Entry(f,width=25)
    v4=IntVar()
    v5=StringVar()
    v6=StringVar()
    s1=Spinbox(window,from_=2015,to=2019,textvariable=v4,width=25) #Adding spin box
    s2=Spinbox(window,value=('AUTUMN','SPRING','SUMMER'),textvariable=v5,width=25)
    e7=Entry(f,width=25)
    e8=Entry(f,width=25)
    s3=Spinbox(window,value=('ENGINEERING','MBA','LAW','MEDICAL SCIENCE','AGRICULTURE','LANGUAGE'),textvariable=v6,width=25)
    e9=Entry(f,width=25)
    label55.place(x=100,y=100)  #use of place manager for placing in the geometry
    label3.place(x=150,y=200)
    label4.place(x=600,y=200)
    label5.place(x=150,y=300)
    label6.place(x=1050,y=200)
    label7.place(x=600,y=300)
    label8.place(x=1050,y=300)
    label9.place(x=150,y=400)
    label10.place(x=600,y=400)
    label11.place(x=1050,y=400)
    label12.place(x=150,y=500)
    label13.place(x=600,y=500)
    e3.place(x=200,y=200)
    e4.place(x=670,y=200)
    e5.place(x=200,y=300)
    c1.place(x=1100,y=200)
    c2.place(x=1100,y=220)
    c3.place(x=1100,y=240)
    e6.place(x=670,y=300)
    s1.place(x=1115,y=300)
    s2.place(x=200,y=400)
    e7.place(x=670,y=400)
    e8.place(x=1115,y=400)
    s3.place(x=200,y=500)
    e9.place(x=670,y=500)
    def file():
        fv1=e3.get()  #use of get() function to retrive the data
        fv2=e4.get()
        fv3=e5.get()
        fv4=e6.get()
        fv5=e9.get()
        fv6=v4.get()                                          
        fv7=v5.get()
        fv8=v6.get()
        fv9=v1.get()
        fv10=v2.get()
        fv11=v3.get()
        if fv9==1:
            fv14="MALE"
        elif fv10==1:
            fv14="FEMALE"
        elif fv11==1:
            fv14="OTHERS"
        else:
            fv14="NOT SELECTED"
        fv12=e7.get()
        fv13=e8.get()
        try:                                                 #Exception Handling
            if open("zzxt.txt","r"):
                
                f=open("zzxt.txt","a") 
                f.write(fv1)                                 #Appending data to file
                f.write("\t")
                f.write(fv2)
                f.write("\t")
                f.write(fv3)
                f.write("\t")
                f.write(fv4)
                f.write("\t")
                f.write(fv5)
                f.write("\t")
                f.write(fv13)
                f.write("\t")
                f.write(fv12)
                f.write("\t")
                f.write(str(fv6))
                f.write("\t")
                f.write(str(fv7))
                f.write("\t")
                f.write(str(fv8))
                f.write("\t")
                f.write(fv14)
                f.write("\n")
                f.close()
            messagebox.showinfo("show info","YOUR RESPONSE HAS BEEN RECORDED PRESS EXIT TO LEAVE")#showing message for saved data
        except:
            f=open("zzxt.txt","w") # Writing to file
            f.write(fv1)
            f.write("\t")
            f.write(fv2)
            f.write("\t")
            f.write(fv3)
            f.write("\t")
            f.write(fv4)
            f.write("\t")                       
            f.write(fv5)
            f.write("\t")
            f.write(fv13)
            f.write("\t")
            f.write(fv12)
            f.write("\t")
            f.write(str(fv6))
            f.write("\t")
            f.write(str(fv7))
            f.write("\t")
            f.write(str(fv8))
            f.write("\t")
            f.write(fv14)
            f.write("\t")
            f.close()
            messagebox.showinfo("show info","YOUR RESPONSE HAS BEEN RECORDED PRESS EXIT BUTTON TO LEAVE")
       
    l5=Button(window,text="SAVE",width=25,command=file)
    l5.place(x=200,y=600)
   
    

    
        
def signin():                        #sign in module for admin
    l1.destroy()
    l2.destroy()
    label56=Label(text="ENTER YOUR CREDENTIALS CAREFULLY")
    label1=Label(text="USERNAME")
    label2=Label(text="PASSWORD")
    e1=Entry(f,width=35)
    e2=Entry(f,width=35,show='*')
    label56.place(x=50,y=100)
    label1.place(x=50,y=150)
    label2.place(x=50,y=200)
    e1.place(x=200,y=150)
    e2.place(x=200,y=200)
    def show1():
        str1=e1.get()
        str2=e2.get()
        label56.destroy()#destroying the label
        label1.destroy()
        label2.destroy()
        e1.destroy()
        e2.destroy()
        l4.destroy()
        if(str1=="115050" and str2=="lpu@123"):
            try:
                
                f=open("zzxt.txt","r")
                data=f.readline()                               #reading provided data from file
                data1=f.readline()
                data2=f.read(150)
                data3=f.read(150)
                data4=f.read(150)
                f.close()
                p=Label(text="DATA SAVED IN THE MANNER :   NAME    LASTNAME    ID    SECTION    TOPIC    MAIL-ID    CELLNO.    SESSION    TERM    FIELD    GENDER :")
                p1=Label(text="1." + data)
                p2=Label(text="2. " + data1)                     
                p3=Label(text="3. " + data2)
                p4=Label(text="4. " + data3)
                p5=Label(text="5. " + data4)
                p.place(x=50,y=250)
                p1.place(x=60,y=300)
                p2.place(x=60,y=350)
                p3.place(x=60,y=400)
                p4.place(x=60,y=450)
                p5.place(x=60,y=500)
            except:
                lp=Label(text="NOT DATA AVAILABLE")
                lp.place(x=100,y=200)
        else:
            messagebox.showerror("show error","wrong credentials")# showing message for wrong credentials
            
    l4=Button(window,text="sign in ",command=show1)
    l4.place(x=500,y=190)
    
#View Interface
#adding Buttons


l1=Button(f,text="REGISTER",width=10, command=l)# here command redirect the flow of exceution to the function that is mentioned
l1.place(x=500,y=50)
l2=Button(f, text="SIGN IN ",width=10, command=signin)
l2.place(x=600,y=50)
l3=Button(f,text="EXIT",width=10,command=window.destroy) #window.destroy destroy the whole window and the event come out of loop
l3.place(x=700,y=50)


        
    
window.mainloop()                  #Tkinter event loop
